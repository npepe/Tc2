# %% [markdown]
# # Teoría de Circuitos II
#
# # Trabajo semanal 10
# ####

# %% [markdown]
# ### Parte I -Ejercicio de MAI
#
# Síntesis de funciones de excitación
# 1) Sea la función:
#
# ![image.png](attachment:image.png)
#
# Se pide hallar la topología circuital y los valores de los componentes para:
#
# a) Síntesis de Z(s) mediante el método de Foster en su versión  "paralelo" o "derivación".
#
# b) Idem a) mediante Cauer 1 y 2.
#
# 2) Sea
#
# ![image-2.png](attachment:image-2.png)
#
# Obtenga los valores de los componentes de la siguiente red sabiendo que L2 y C2 resuenan a 1 r/s.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Punto 1.a
#
# Sintetizo mediante Foster en "Serie":
#
# \begin{equation}
# Z(S) = \frac{(S^2+3)(S^2+1)}{(S^2+2)S}
# \end{equation}
#
# Analizo que ocurre cuando tiende a 0 para remover el polo en 0.
#
# \begin{equation}
# Z(S) = \frac{(S^2+3)(S^2+1)}{(S^2+2)S} = \frac{Ko}{S}
# \end{equation}
#
# \begin{equation}
# Ko=\frac{3}{2}
# \end{equation}
#
#
# Repito con el polo en el 2 para obtener el tanque inductor capacitor:
#
# \begin{equation}
# Z(S) = \frac{(S^2+3)(S^2+1)}{(S^2+2)S} = \frac{2*K1*S}{(S^2+2)}
# \end{equation}
#
# \begin{equation}
# K1=\frac{1}{4}
# \end{equation}
#
# Repito con el polo en infinito:
#
# \begin{equation}
# Z(S) = \frac{(S^2+3)(S^2+1)}{(S^2+2)S} = K2*S
# \end{equation}
#
# \begin{equation}
# K2=1
# \end{equation}
#
# Finalmente obtengo:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Punto 1.b
#
# Sintetizo mediante Couer:
#
# \begin{equation}
# Z(S) = \frac{(S^2+3)(S^2+1)}{(S^2+2)S}
# \end{equation}
#
# Partiendo de Z(S), voy removiendo reciduos, al partir de Z(s) lo primero que removere sera un polo (que al sintetizarlo dara un capacitor)
#
# \begin{equation}
# \frac{(S^4+4S^2+3)}{S^3+2S}
# \end{equation}
#
# Obtengo K1=S, para ahora remover el reciduo en Y(s) invierto y repito el proceso dividiendo por el:
#
# \begin{equation}
# \frac{S^3+2S}{2S^2+3}
# \end{equation}
#
# Obtengo K2 = S/2
#
# \begin{equation}
# \frac{2S^2+3}{\frac{S}{2}}
# \end{equation}
#
# Obtengo K3 = 4*S
#
# \begin{equation}
# \frac{\frac{S}{2}}{3}
# \end{equation}
#
# Obtengo K4 = S/6
#
# Finalmente obtengo la sintesis:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Punto 2
#
# Siendo que nos dan como condicion que L2 y C2 resuenan en 1 rad/seg , para ello debemos desplazar un cero gasta f=1 y para ello se debe aplicar remociones parciales.
#
# \begin{equation}
# Z(S) = \frac{(S^2+2)(S^2+5)}{3S(S^2+\frac{7}{3})}
# \end{equation}
#
# Analizo la conducta cuando S^2 -> -1
#
# \begin{equation}
# \frac{(-1+2)(-1+5)}{3(-1)(-1+\frac{7}{3})}= Ko = 1
# \end{equation}
#
# Remuevo parcialmente el reciduo:
#
# \begin{equation}
# Z1(S) = Z(S) - Ko/S
# \end{equation}
#
# Trabajo con la nueva Z(S):
#
# \begin{equation}
# Z1(S) = \frac{(S^2+1)(S^2+3)}{3S(S^2+\frac{7}{3})}
# \end{equation}
#
# Sabiendo que buscamos que sean dos tanques en derivacion aplicamos Foster en derivacion:
#
# \begin{equation}
# Y1(S) = \frac{3S(S^2+\frac{7}{3})}{(S^2+1)(S^2+3)}
# \end{equation}
#
# Remuevo los dos tanques en derivacion en  -1 y -3
#
# \begin{equation}
# Y1(S) = \frac{3S(S^2+\frac{7}{3})}{2(S^2+3)} = K1 = 1
# \end{equation}
#
# \begin{equation}
# Y1(S) = \frac{3S(S^2+\frac{7}{3})}{2(S^2+1)} = K2 = \frac{1}{2}
# \end{equation}
#
# Finalmente se obtuvo que:
#
# ![image.png](attachment:image.png)
