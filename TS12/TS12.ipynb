# %% [markdown]
# # Teoría de Circuitos II
#
# # Trabajo semanal 12
# ####

# %% [markdown]
# 1) Ej. 6 TP Síntesis de Cuadripolos
#
# Sintetizar un cuadripolo que cumpla con los siguientes parámetros:
#
# ![image.png](attachment:image.png)
#
# a) Obtener la topología mediante la síntesis gráfica, es decir la red sin valores.
#
# b) Calcular el valor de los componentes, es decir la síntesis analítica.
#
#
# 2) Dada la siguiente transferencia:
#
# ![image-2.png](attachment:image-2.png)
#
# a) Obtener la topología circuital que respeta la transferencia solicitada, utilizando parámetros Z e Y.
#
# b) Calcular el valor de los componentes y el parámetro k.

# %% [markdown]
# Punto A:
#
# El punto a se adjunta en formato pdf.
#
# Punto B:
#
# Sintesis analitica
#
# \begin{equation}
# Z(S) = \frac{(S^2+2)(S^2+5)}{(S^2+\frac{7}{3})(3*S)}
# \end{equation}
#
# Remuevo parcialmente reciduo en 0, analizo en S^2 = -1:
#
# \begin{equation}
# Z(-1) = \frac{((-1)+2)((-1)+5)}{((-1)+\frac{7}{3})(3*S)} = \frac{Ko}{S}
# \end{equation}
#
# Obtengo que Ko = 1 , obtengo un capacitor en serie
#
# \begin{equation}
# Za(S) = \frac{(S^2+2)(S^2+5)}{(S^2+\frac{7}{3})(3*S)} - \frac{1}{S}
# \end{equation}
#
# Se comprueba que cumplo la condicion de un cero en 1
#
# \begin{equation}
# Za(S) = \frac{(S^2+1)(S^2+3)}{(S^2+\frac{7}{3})(3*S)}
# \end{equation}
#
# Remuevo reciduos en 1:
#
# \begin{equation}
# Ya(S) = \frac{(S^2+\frac{7}{3})(3*S)}{(S^2+1)(S^2+3)} = \frac{2*K1*S}{(S^2+1)}
# \end{equation}
#
# \begin{equation}
# Ya(S) = \frac{(S^2+\frac{7}{3})(3)}{(S^2+3)}  = 2*K1
# \end{equation}
#
# \begin{equation}
# Ya(S) = \frac{3((-1)+\frac{7}{3})}{2(-1)+3)}  =K1=1
# \end{equation}
#
# Obtengo un tanque inductor capacitor en derivacion de valores L1=1/2 y C2=2:
#
# \begin{equation}
# Yb(S) = \frac{(S^2+\frac{7}{3})(3*S)}{(S^2+1)(S^2+3)} -\frac{2*S}{(S^2+1)}
# \end{equation}
#
# \begin{equation}
# Yb(S) = \frac{(S)}{(S^2+3)}
# \end{equation}
#
# Aplico Couer para sintetizar los componentes que faltan:
#
# \begin{equation}
# Zb(S) = \frac{(S^2+3)}{(S)}
# \end{equation}
#
# \begin{equation}
# \frac{(S^2+3)}{(S)}
# \end{equation}
#
# Obtengo un inductor en serie de valor L2=1
#
# \begin{equation}
# \frac{S}{3}
# \end{equation}
#
# Obtengo un capacitor en derivacion de valor C3=1/3
#
# Finalmente la sintesis resultaria en:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Punto 2
#
# a) Se adjunta analisis Grafica en Pdf
#
# b)
#
# Remuevo parcialmente en cero para desplazar el cero a sigma igual -1:
#
# \begin{equation}
# Y11(-1) = \frac{(S+2)(S+4)}{(S+3)} = Ko = \frac{3}{2}
# \end{equation}
#
# \begin{equation}
# Ya(S) = Y11(S) - Ko
# \end{equation}
#
# \begin{equation}
# Ya(S) = \frac{(S+2)(S+4)}{(S+3)} - \frac{3}{2}
# \end{equation}
#
# \begin{equation}
# Ya(S) = \frac{(S+1)(S+\frac{7}{2})}{(S+3)}
# \end{equation}
#
# \begin{equation}
# Za(S) = \frac{(S+3)}{(S+1)(S+\frac{7}{2})}
# \end{equation}
#
#
# Remuevo el polo en sigma igual a -1:
#
# \begin{equation}
# Za(-1) = \frac{(S+3)}{(S+1)(S+\frac{7}{2})} = \frac{K1}{(S+1)}
# \end{equation}
#
# Obtengo que el reciduo K1 = 4/5
#
# \begin{equation}
# Zb(S) = Ya(S) - \frac{K1}{(S+1)}
# \end{equation}
#
# \begin{equation}
# Zb(S) = \frac{(S+3)}{(S+1)(S+\frac{7}{2})} - \frac{\frac{4}{5}}{(S+1)}
# \end{equation}
#
# \begin{equation}
# Zb(S) = \frac{1}{5(S+\frac{7}{2})}
# \end{equation}
#
# \begin{equation}
# Yb(S) = 5(S+\frac{7}{2})
# \end{equation}
#
# Remuevo el polo en infinito
#
# \begin{equation}
# 5(S+\frac{7}{2})=S K2
# \end{equation}
#
# Obtengo que el reciduo K2 = 5
#
# Remuevo el residuo restante para obtener la resistencia en serie de la entrada
# K3=2/35
#
# Finalmente se obtuvo la siguiente sintesis:
#
# ![image.png](attachment:image.png)
