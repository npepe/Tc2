# %% [markdown]
# <img src="./logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Trabajo practico 1
# ####

# %% [markdown]
# 1)
# Partiendo de las siguientes estructuras circuitales, se requiere diseñar un amplificador inversor cuya impedancia de entrada Z1=10 kΩ y su transferencia de tensión V2/V1=-3000 Analizar ventajas y desventajas de cada circuito.
# ![image-3.png](attachment:image-3.png)
#
# a)
# \begin{equation}
# {Ir1 + Ir2}=0
# \end{equation}
#
# \begin{equation}
# {\frac{V1}{R1}}=\frac{-V2}{R2}= 3000
# \end{equation}
#
# Sabiendo que la ganancia es de 3000 y que la R1 esta fijada en 10 Kohm , la resistencia R2 necesaria seria de 30.000 Kohm
#
# \begin{equation}
#  3000 * 10 Kohm = R2 ==> R2 = 30.0000 Kohm
# \end{equation}
#
#
# Debido a la tension a la salida del opam esta fijada en V2, R3 podria tener cualquier valor
#
#
# b)
# Planteo el sistema de corrientes
#
# \begin{equation}
# {Ir1 + Ir2}=0
# \end{equation}
#
# \begin{equation}
# {Ir2 + Ir4 + Ir3}= 0
# \end{equation}
#
# Busco hallar por sistema de ecuaciones que las corrientes queden en funcion de las tensiones y las resistencias
#
# \begin{equation}
# {\frac{V1}{R1}}=\frac{-Vx}{R2}
# \end{equation}
#
# repito el proceso con las resistencias en T
#
# \begin{equation}
# {\frac{Vx}{R2}} + \frac{Vx-V2}{R3} + \frac{Vx}{R4} = 0
# \end{equation}
#
# Desarrollo algebraicamente y obtengo (tomando a V2 / V1 = -3000)
#
# \begin{equation}
# {\frac{R2*R3 + R2*R4 + R3*R4}{R1*R2*R3*R4}} * (-R2*R3)= -3000
# \end{equation}
#
# Normalizo diciendo que :
# R2 = R3
# R4 = 2(R2)
#
# lo que se me simplifica en:
# \begin{equation}
# \frac{5}{2} * R2 = 3000 * R1
# \end{equation}
#
# Finalmente como R1 = 10 K ohm
#
# \begin{equation}
# R2 = R3 = 12 Mohm
# \end{equation}
#
# \begin{equation}
# R4= 24 Mohm
# \end{equation}
#
#
# c)
# Tomo a la parte derecha del circuito como una resistencia Z2 y la corriente de salida de la izquierda como gm1*V1 y
# siendo:
#
# \begin{equation}
# Z2 = \frac{-1}{gm2}
# \end{equation}
#
#  y
#
#  \begin{equation}
# V2 = (gm1*V1)*Z2
# \end{equation}
#
# \begin{equation}
# {\frac{V1}{V2}}=-3000={gm1}{\frac{-1}{gm2}}
# \end{equation}
#
# Finalmente la condicion necesaria para la ganancia perdida deberia ser:
# \begin{equation}
# 3000 = \frac{gm1}{gm2}
# \end{equation}

# %% [markdown]
# 6) Para el siguiente dipolo activo determinar la impedancia de excitación.
#
# a) Indique/proponga aplicaciones para esta red.
#
# b) Investigue sobre la posibilidad de obtener el mismo comportamiento utilizando OTA (Ver Cap. 16.2 Schaumann).
#
# ![image.png](attachment:image.png)
#
# Se plantea las corrientes y dejandolas en funcion de las tenciones
#
# \begin{equation}
# {Iin}=\frac{V1-Vo}{R1}
# \end{equation}
#
# \begin{equation}
# {Zin}=\frac{-R2*Zl}{R1}
# \end{equation}
#
# Simplificando R2/R1 = K
# \begin{equation}
# {Zin}={K*Zl}
# \end{equation}
#
# a) Este circuito es conocido como NIC (negative impedance converter) y como bien lo indica su nombre funciona como una imoedancia negativa, esto se logra invirtiendo la polaridad de la tension o la dirección de la corriente de entrada e induce un cambio de fase de 180 ° entre la tencion y la corriente para cualquier generador de señal.
#
# b)
#
# ![image-2.png](attachment:image-2.png)
