# %% [markdown]
# # Teoría de Circuitos II
#
# # Trabajo semanal 13
# ####

# %% [markdown]
# 1) Ejercicio 5 TP 7
#
# Sintetice la siguiente transferencia cargada con componentes RC:
#
# ![image.png](attachment:image.png)
#
# a) Obtener la topología mediante la síntesis gráfica, es decir la red sin valores.
#
# b) Calcular el valor de los componentes, es decir la síntesis analítica.
#
# 2) Dada la siguiente transferencia de impedancia:
#
# ![image-2.png](attachment:image-2.png)
#
# a) Sintetizar un cuadripolo pasivo sin pérdidas, que cumpla con la transimpedancia indicada, cargado a la salida con una impedancia como se muestra en la figura.
#
# b) Verificar la transimpedancia del circuito obtenido.

# %% [markdown]
# Punto 1
#
# A) Realizado en archivo adjunto
#
# B) Sintesis analitica:
#
# Remuevo la resistencia normalizada en 1 Rl que me impone la topologia
#
# \begin{equation}
# Z1(S) = \frac{6(S^2+8S+12)}{(S^2+5S+4)}
# \end{equation}
#
#
# \begin{equation}
# Za(S) = \frac{6(S^2+8S+12)}{(S^2+5S+4)} -1
# \end{equation}
#
# \begin{equation}
# Za(S) = \frac{5S^2+43S+68)}{(S+1)(S+4)}
# \end{equation}
#
# Retiro polo en sigma=-1 para obtener un tanque RC en serie:
#
# \begin{equation}
# Za(-1) = \frac{5S^2+43S+68)}{(S+1)(S+4)}=\frac{K1}{(S+1)}
# \end{equation}
#
# Obtengo K1=10
#
# \begin{equation}
# Zb(S) = \frac{5S^2+43S+68)}{(S+1)(S+4)}-\frac{10}{(S+1)}
# \end{equation}
#
# \begin{equation}
# Zb(S) = 5\frac{S+\frac{28}{5}}{(S+4)}
# \end{equation}
#
# Retiro el otro Polo en sigma = -4 y obtengo un segundo tanque:
#
# \begin{equation}
# Zb(-4) = 5\frac{S+\frac{28}{5}}{(S+4)}=\frac{K2}{(S+4)}
# \end{equation}
#
# Obtengo K2=8
#
# \begin{equation}
# Zc(S)= 5\frac{S+\frac{28}{5}}{(S+4)}-\frac{8}{(S+4)}
# \end{equation}
#
# Zc(S)=5
#
# Obtengo la impedancia restante de valor 5.

# %% [markdown]
# Punto 2
#
# a)
#
# Sabiendo que es un cuadripolo sin perdidas:
# \begin{equation}
# V2= (-I2)*Rl
# \end{equation}
#
# \begin{equation}
# V2= I1*Z21 + (-I2)*Z22
# \end{equation}
#
# Planteo la relacion entre V2 y I1 y obtengo:
#
# \begin{equation}
# \frac{V2}{I1} = \frac{Z21*Rl}{Rl+Z22}
# \end{equation}
#
# Si normalizo Rl=1:
#
# \begin{equation}
# T(S) = \frac{Z21}{1+Z22}
# \end{equation}
#
# Al ser No disipativo, aplico condiciones de paridad e impongo la imparidad en Z21:
#
# \begin{equation}
# Z21 = \frac{S^2+9}{S^3+2S}
# \end{equation}
#
# \begin{equation}
# Z22 = \frac{2S^2+1}{S^3+2S}
# \end{equation}
#
# Remplazo:
# \begin{equation}
# T(S) = \frac{\frac{S^2+9}{S^3+2S}}{1+\frac{2S^2+1}{S^3+2S}}
# \end{equation}
#
# Sintetizo Z22 (Sintesis grafica en archivo adjunto)
#
# \begin{equation}
# Y22 = \frac{S^3+2S}{2S^2+1}
# \end{equation}
#
# Remuevo parcialmente en infinito:
#
# \begin{equation}
# Y22(-3)= \frac{S((-3)+2)}{(-3)+1}=K1*S
# \end{equation}
#
# Obtengo residuo K1 = 1/5 (representado por un capacitor en derivacion)
#
# \begin{equation}
# Ya = \frac{S^3+2S}{2S^2+1}-K1*S
# \end{equation}
#
#
# \begin{equation}
# Ya = \frac{\frac{3}{5}S^3+\frac{9}{5}S}{2S^2+1}
# \end{equation}
#
# Remuevo totalmente polo en sigma = -3:
#
# \begin{equation}
# Za = \frac{2S^2+1}{\frac{3}{5}S^3+\frac{9}{5}S}
# \end{equation}
#
# \begin{equation}
# Za(-3) = \frac{2S^2+1}{\frac{3}{5}S^3+\frac{9}{5}S}=\frac{2*K2*S}{S^2+3}
# \end{equation}
#
# Obtengo que el residuo K2=25/18 representado por un tanque en serie LC:
#
# Remuevo el ultimo polo:
#
# \begin{equation}
# Zb= \frac{2S^2+1}{\frac{3}{5}S^3+\frac{9}{5}S}-\frac{2*\frac{25}{18}*S}{S^2+3}
# \end{equation}
#
# \begin{equation}
# Zb= \frac{5*S}{9}
# \end{equation}
#
# \begin{equation}
# Yb= \frac{9}{5*S}
# \end{equation}
#
# Remuevo en infinito y obtengo K3=9/5 representado por un capacitor en derivacion.
#
# Finalmente se obtuvo la sintesis esperada :
#
# ![image.png](attachment:image.png)
