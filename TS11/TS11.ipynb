# %% [markdown]
# # Teoría de Circuitos II
#
# # Trabajo semanal 11
# ####

# %% [markdown]
# Síntesis de funciones de excitación disipativas
#
# ![image.png](attachment:image.png)
#
# 1) Encuentre el valor de los componentes del siguiente circuito:
#
# ![image-2.png](attachment:image-2.png)
#
# 2) Determine el valor de los componentes que integran el siguiente dipolo, sabiendo que satisface la impedancia propuesta:
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Punto 1
#
# Siendo que para cumplir con ambas condiciones C1 y C2 debemos primero mover los ceros hacia esos puntos (-6 y -7/2):
#
# \begin{equation}
# Z(S) = \frac{(S+2)(S+4)}{(S+1)(S+3)}
# \end{equation}
#
# Trabajaremos con Y(S):
#
# \begin{equation}
# Y(S) = \frac{(S+1)(S+3)}{(S+2)(S+4)}
# \end{equation}
#
# Sabiendo que :
#
# \begin{equation}
# Y1(S) = \frac{S*K1}{S*+6}
# \end{equation}
#
# \begin{equation}
# Y2(S) = \frac{S*K2}{S+\frac{7}{2}}
# \end{equation}
#
# Remuevo parcialmente el polo para mover el cero:
#
# Analizo cuando S tiende a -6
# \begin{equation}
# \frac{((-6)+1)((-6)+3)}{((-6)+2)((-6)+4)} = \frac{15}{8}
# \end{equation}
#
# \begin{equation}
# Z1 = \frac{8}{15}
# \end{equation}
#
# Remuevo el Z1 del Ztotal para seguir con la sintesis:
#
# \begin{equation}
# Za(S) = Z(S)-Z1 = \frac{\frac{7}{15}*(S+\frac{16}{7})(S+6)}{(S+1)(S+3)}
# \end{equation}
#
#
# Se observa que cumple con la condicion solicitada de tener un polo en -6 en admitancia:
#
# \begin{equation}
# Ya(S) = \frac{\frac{15}{7}*(S+1)(S+3)}{(S+\frac{16}{7})(S+6)}
# \end{equation}
#
# Prosigo a quitar la rama de R1 y C1
#
# \begin{equation}
# Ya(-6) = \frac{\frac{15}{7}*((-6)+1)((-6)+3)}{(-6)*((-6)+\frac{16}{7})} = K1 = \frac{75}{52}
# \end{equation}
#
# Sabiendo el valor de C1=K1 , despejo de la ecuacion original y obtengo el valor de R1:
#
# \begin{equation}
# R1= \frac{1}{C1}*\frac{1}{6} = \frac{25}{104}
# \end{equation}
#
#
# Remuevo la rama R1,C1:
#
# \begin{equation}
# Yb(S) = Ya(S)-\frac{\frac{75}{52}*S}{(S+6)}
# \end{equation}
#
# \begin{equation}
# Yb(S) = \frac{364}{255}* \frac{(S+\frac{16}{7})}{(S+\frac{26}{17})}
# \end{equation}
#
# Una vez obtenido el Yb repito el mismo procedimiento que hicimos con Z1, R1 y C1
#
# Analizo cuando S tiende a -7/2
#
# \begin{equation}
# \frac{((\frac{7}{2})+1)((\frac{7}{2})+3)}{((\frac{7}{2})+2)((\frac{7}{2})+4)} = \frac{884}{1005}
# \end{equation}
#
# \begin{equation}
# Z3 = \frac{884}{1005}
# \end{equation}
#
# Remuevo el Z3 del Ztotal para seguir con la sintesis:
#
# \begin{equation}
# Zb(S) = Za(S)-Z3 = \frac{\frac{9360}{67}*(S+\frac{7}{2})}{255*(S+\frac{26}{17})}
# \end{equation}
#
#
# Se observa que cumple con la condicion solicitada de tener un polo en -7/2 en admitancia:
#
# \begin{equation}
# Yb(S) =  \frac{\frac{1139}{624}*(S+\frac{26}{17})}{(S+\frac{7}{2})}
# \end{equation}
#
# Prosigo a quitar la rama de R2 y C2
#
# \begin{equation}
# Yb(-\frac{7}{2}) =  \frac{\frac{1139}{624}*((-\frac{7}{2})+\frac{26}{17})}{-\frac{7}{2}}=K2 = \frac{4489}{4368}
# \end{equation}
#
# Sabiendo el valor de C2=K2 , despejo de la ecuacion original y obtengo el valor de R1:
#
# \begin{equation}
# R2= \frac{1}{C2}*\frac{2}{7} = \frac{1248}{4489}
# \end{equation}
#
# Prosigo con la Z5 restante:
#
# \begin{equation}
# Yc(S) = Yb(S)-\frac{\frac{4489}{4368}*S}{(S+\frac{7}{2})}
# \end{equation}
#
# Obtenemos la Z3:
#
# \begin{equation}
# Yc(S) = \frac{67}{84}
# \end{equation}
#
# \begin{equation}
# Zc(S) = \frac{84}{67}=Z3
# \end{equation}
#
# Finalmente obtenemos la siguiente sintesis:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Punto 2
#
# Sabiendo que debo partir de Y(S) ya que el primer componente es un capacitor en derivacion :
#
# \begin{equation}
# Y(S) = \frac{(S^3 + 3S^2 + 7S + 5)}{(S^2+S+1)}
# \end{equation}
#
# Remuevo el primer capacitor C1 por Couer:
#
# \begin{equation}
# \frac{(S^3 + 3S^2 + 7S + 5)}{(S^2+S+1)}
# \end{equation}
#
# Obtengo que el valor de es C1 = 1
#
# \begin{equation}
# Ya(S) = \frac{(S^3 + 3S^2 + 7S + 5)}{(S^2+S+1)} - SC1 = \frac{(2S^2 + 6S + 5)}{(S^2+S+1)}
# \end{equation}
#
# Repito para obtener el R1 , me doy cuenta que voy por buen camino ya que el denominador y numerador son del mismo orden , por lo que se obtendra sera si o si una resitencia en derivacion.
#
# \begin{equation}
# \frac{(2S^2 + 6S + 5)}{(S^2+S+1)}
# \end{equation}
#
# Obtengo el valor de 2, pero es un valor de admitancia, por lo que el valor de R1 sera de 1/2.
# Remuevo ese reciduo y sabiendo que el siguiente sera en serie trabajo con la Z(s)
#
# \begin{equation}
# Zb(s)= \frac{(S^2 + S + 1)}{(4S+3)}
# \end{equation}
#
# Busco el valor de L1:
# \begin{equation}
# \frac{(S^2 + S + 1)}{(4S+3)}
# \end{equation}
#
# Obtengo que L1 = 1/4
# Sabiendo que el Resistor que sigue estara en serie repito el mismo procedimiento:
#
# \begin{equation}
# Zc(S)=\frac{(S^2 + S + 1)}{(4S+3)}-\frac{s}{4}
# \end{equation}
#
# \begin{equation}
# Zc(s)= \frac{(S+4)}{16S+3}
# \end{equation}
#
# Obtengo que R2 es 1/16
#
# \begin{equation}
# Zd(s)= \frac{(S+4)}{16S+3} - \frac{1}{16}
# \end{equation}
#
#
# \begin{equation}
# Ze(s)= \frac{61}{2565S+48}
# \end{equation}
#
# Repito lo planteado en un principio para obtener C2 Y R3
#
# \begin{equation}
# Ye(s)= \frac{256S+48}{61}
# \end{equation}
#
# Resuelvo la divicion y obtengo C2 = 256/61 y R=61/48
#
# Finalmente se obtuvo:
#
# ![image.png](attachment:image.png)

# %%
\frac{7}{2}
